# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow import keras
from sklearn.model_selection import StratifiedKFold

from utilities import load_data

# %%
np.random.seed(0)
X_high,y_high = load_data(100, amplitude=10)
X, y = load_data(200, amplitude=1)
X_low = X[200:]
y_low = y[200:]

# %%
skfold = StratifiedKFold(n_splits=5)

acc_per_fold_high = []
acc_per_fold_low = []
loss_per_fold = []

for train, test in skfold.split(X_high,y_high):

    #define the model
    model = keras.models.Sequential()
    
    model.add(keras.layers.Conv2D(32, (3, 3), activation='tanh', input_shape=X.shape[1:]))
    model.add(keras.layers.AveragePooling2D((3, 3)))
    
    model.add(keras.layers.Conv2D(16, (3, 3), activation='tanh'))
    model.add(keras.layers.AveragePooling2D((2, 2)))
    
    model.add(keras.layers.Conv2D(8, (3, 3), activation='tanh'))
    model.add(keras.layers.AveragePooling2D((2, 2)))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(1, activation='sigmoid'))
    
    if len(acc_per_fold_high)==0 : model.summary()
    #compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

    #fit the model
    history = model.fit(X_high[train], y_high[train], epochs=10, batch_size=25, verbose=1)

    #evaluate the model
    print('\nEvaluation of the model : \n')
    print('Train set : \n')
    model.evaluate(X_high[train], y_high[train])
    print('Test set(10**-6) : \n')
    scores_high = model.evaluate(X_high[test], y_high[test])
    print('Test set(10**-7) : \n')
    scores_low = model.evaluate(X_low[test], y_low[test])
    
    acc_per_fold_high.append(scores_high[1] * 100)
    acc_per_fold_low.append(scores_low[1] * 100)

    print("\n-----------------------------------\n")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 398, 398, 32)      320
# _________________________________________________________________
# average_pooling2d_6 (Average (None, 132, 132, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 130, 130, 16)      4624
# _________________________________________________________________
# average_pooling2d_7 (Average (None, 65, 65, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 63, 63, 8)         1160
# _________________________________________________________________
# average_pooling2d_8 (Average (None, 31, 31, 8)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7688)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7689
# =================================================================
# Total params: 13,793
# Trainable params: 13,793
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 7/7 [==============================] - 5s 727ms/step - loss: 0.6732 - acc: 0.6438
# Epoch 2/10
# 7/7 [==============================] - 5s 694ms/step - loss: 0.5403 - acc: 0.8062
# Epoch 3/10
# 7/7 [==============================] - 5s 686ms/step - loss: 0.2723 - acc: 0.9750
# Epoch 4/10
# 7/7 [==============================] - 5s 712ms/step - loss: 0.0586 - acc: 0.9937
# Epoch 5/10
# 7/7 [==============================] - 5s 688ms/step - loss: 0.0187 - acc: 1.0000
# Epoch 6/10
# 7/7 [==============================] - 5s 681ms/step - loss: 0.0282 - acc: 0.9875
# Epoch 7/10
# 7/7 [==============================] - 5s 699ms/step - loss: 0.0257 - acc: 0.9937
# Epoch 8/10
# 7/7 [==============================] - 5s 681ms/step - loss: 0.0231 - acc: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 5s 704ms/step - loss: 0.0077 - acc: 1.0000
# Epoch 10/10
# 7/7 [==============================] - 5s 667ms/step - loss: 0.0017 - acc: 1.0000
#
# Evaluation of the model :
#
# Train set :
#
# 5/5 [==============================] - 1s 275ms/step - loss: 1.0702e-04 - acc: 1.0000
# Test set(10**-6) :
#
# 2/2 [==============================] - 0s 44ms/step - loss: 4.4238e-06 - acc: 1.0000
# Test set(10**-7) :
#
# 2/2 [==============================] - 0s 45ms/step - loss: 4.1574 - acc: 0.5000
#
# -----------------------------------
#
# Epoch 1/10
# 7/7 [==============================] - 5s 697ms/step - loss: 0.6703 - acc: 0.5938
# Epoch 2/10
# 7/7 [==============================] - 5s 700ms/step - loss: 0.5476 - acc: 0.7625
# Epoch 3/10
# 7/7 [==============================] - 5s 686ms/step - loss: 0.3151 - acc: 0.8875
# Epoch 4/10
# 7/7 [==============================] - 5s 704ms/step - loss: 0.0933 - acc: 0.9937
# Epoch 5/10
# 7/7 [==============================] - 5s 697ms/step - loss: 0.0219 - acc: 1.0000
# Epoch 6/10
# 7/7 [==============================] - 5s 692ms/step - loss: 0.0046 - acc: 1.0000
# Epoch 7/10
# 7/7 [==============================] - 5s 709ms/step - loss: 7.0701e-04 - acc: 1.0000
# Epoch 8/10
# 7/7 [==============================] - 5s 685ms/step - loss: 6.0355e-04 - acc: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 5s 691ms/step - loss: 1.0720e-04 - acc: 1.0000
# Epoch 10/10
# 7/7 [==============================] - 5s 690ms/step - loss: 8.6737e-05 - acc: 1.0000
#
# Evaluation of the model :
#
# Train set :
#
# 5/5 [==============================] - 1s 277ms/step - loss: 9.5786e-05 - acc: 1.0000
# Test set(10**-6) :
#
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0013 - acc: 1.0000
# Test set(10**-7) :
#
# 2/2 [==============================] - 0s 47ms/step - loss: 2.9360 - acc: 0.5750
#
# -----------------------------------
#
# Epoch 1/10
# 7/7 [==============================] - 5s 718ms/step - loss: 0.6692 - acc: 0.6438
# Epoch 2/10
# 7/7 [==============================] - 5s 744ms/step - loss: 0.5285 - acc: 0.8625
# Epoch 3/10
# 7/7 [==============================] - 5s 716ms/step - loss: 0.3006 - acc: 0.9312
# Epoch 4/10
# 7/7 [==============================] - 5s 731ms/step - loss: 0.0757 - acc: 1.0000
# Epoch 5/10
# 7/7 [==============================] - 5s 732ms/step - loss: 0.0379 - acc: 0.9812
# Epoch 6/10
# 7/7 [==============================] - 5s 715ms/step - loss: 0.0041 - acc: 1.0000
# Epoch 7/10
# 7/7 [==============================] - 5s 732ms/step - loss: 0.0130 - acc: 0.9937
# Epoch 8/10
# 7/7 [==============================] - 5s 717ms/step - loss: 0.0032 - acc: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 5s 717ms/step - loss: 4.1452e-04 - acc: 1.0000
# Epoch 10/10
# 7/7 [==============================] - 5s 735ms/step - loss: 0.0013 - acc: 1.0000
#
# Evaluation of the model :
#
# Train set :
#
# 5/5 [==============================] - 1s 292ms/step - loss: 2.8512e-04 - acc: 1.0000
# Test set(10**-6) :
#
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0012 - acc: 1.0000
# Test set(10**-7) :
#
# 2/2 [==============================] - 0s 48ms/step - loss: 3.2908 - acc: 0.5750
#
# -----------------------------------
#
# Epoch 1/10
# 7/7 [==============================] - 5s 685ms/step - loss: 0.6743 - acc: 0.5750
# Epoch 2/10
# 7/7 [==============================] - 5s 701ms/step - loss: 0.5558 - acc: 0.7812
# Epoch 3/10
# 7/7 [==============================] - 5s 671ms/step - loss: 0.2963 - acc: 0.9375
# Epoch 4/10
# 7/7 [==============================] - 5s 669ms/step - loss: 0.0867 - acc: 0.9937
# Epoch 5/10
# 7/7 [==============================] - 5s 705ms/step - loss: 0.0355 - acc: 0.9937
# Epoch 6/10
# 7/7 [==============================] - 5s 670ms/step - loss: 0.0070 - acc: 1.0000
# Epoch 7/10
# 7/7 [==============================] - 5s 668ms/step - loss: 0.0041 - acc: 1.0000
# Epoch 8/10
# 7/7 [==============================] - 5s 696ms/step - loss: 3.7019e-04 - acc: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 5s 671ms/step - loss: 0.0062 - acc: 0.9937
# Epoch 10/10
# 7/7 [==============================] - 5s 653ms/step - loss: 0.0020 - acc: 1.0000
#
# Evaluation of the model :
#
# Train set :
#
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0013 - acc: 1.0000
# Test set(10**-6) :
#
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0013 - acc: 1.0000
# Test set(10**-7) :
#
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0852 - acc: 0.6000
#
# -----------------------------------
#
# Epoch 1/10
# 7/7 [==============================] - 5s 723ms/step - loss: 0.6649 - acc: 0.6562
# Epoch 2/10
# 7/7 [==============================] - 5s 735ms/step - loss: 0.5437 - acc: 0.7812
# Epoch 3/10
# 7/7 [==============================] - 5s 713ms/step - loss: 0.3055 - acc: 0.9875
# Epoch 4/10
# 7/7 [==============================] - 5s 716ms/step - loss: 0.1168 - acc: 0.9750
# Epoch 5/10
# 7/7 [==============================] - 5s 775ms/step - loss: 0.0507 - acc: 0.9750
# Epoch 6/10
# 7/7 [==============================] - 4s 604ms/step - loss: 0.0258 - acc: 1.0000
# Epoch 7/10
# 7/7 [==============================] - 4s 599ms/step - loss: 0.0264 - acc: 0.9812
# Epoch 8/10
# 7/7 [==============================] - 4s 628ms/step - loss: 0.0016 - acc: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 4s 602ms/step - loss: 0.0079 - acc: 0.9937
# Epoch 10/10
# 7/7 [==============================] - 4s 633ms/step - loss: 2.6565e-04 - acc: 1.0000
#
# Evaluation of the model :
#
# Train set :
#
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0016 - acc: 1.0000
# Test set(10**-6) :
#
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0016 - acc: 1.0000
# Test set(10**-7) :
#
# 2/2 [==============================] - 0s 47ms/step - loss: 0.8513 - acc: 0.6250
#
# -----------------------------------
