# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow import keras
from sklearn.model_selection import StratifiedKFold

from utilities import load_data_diff_str_tension

# %% [markdown]
# 200 to train on 10^-7, 50 to test on a range of values in 10^-6 to 10^-8. Repeat 3-5 times to get a mean+std.

# %%
dic_X, dic_y = load_data_diff_str_tension(train_tension = 5*10**(-7))

# %%
for key in dic_X.keys():
    print(key, ' : ', dic_X[key].shape)
# Out:
# 1e-08  :  (50, 400, 400, 1)
# 3.1818181818181816e-08  :  (50, 400, 400, 1)
# 5.3636363636363635e-08  :  (50, 400, 400, 1)
# 7.545454545454545e-08  :  (50, 400, 400, 1)
# 9.727272727272726e-08  :  (50, 400, 400, 1)
# 1.1909090909090907e-07  :  (50, 400, 400, 1)
# 1.409090909090909e-07  :  (50, 400, 400, 1)
# 1.627272727272727e-07  :  (50, 400, 400, 1)
# 1.8454545454545454e-07  :  (50, 400, 400, 1)
# 2.0636363636363636e-07  :  (50, 400, 400, 1)
# 2.2818181818181816e-07  :  (50, 400, 400, 1)
# 2.5e-07  :  (50, 400, 400, 1)
# train  :  (200, 400, 400, 1)

# %%
for key in dic_y.keys():
    print(key, ' : ', dic_y[key].shape)
# Out:
# 1e-08  :  (50,)
# 3.1818181818181816e-08  :  (50,)
# 5.3636363636363635e-08  :  (50,)
# 7.545454545454545e-08  :  (50,)
# 9.727272727272726e-08  :  (50,)
# 1.1909090909090907e-07  :  (50,)
# 1.409090909090909e-07  :  (50,)
# 1.627272727272727e-07  :  (50,)
# 1.8454545454545454e-07  :  (50,)
# 2.0636363636363636e-07  :  (50,)
# 2.2818181818181816e-07  :  (50,)
# 2.5e-07  :  (50,)
# train  :  (200,)

# %%
tryout = []
for i in range(10):
    #Train and fit model on 200 samples.
    X,y = dic_X['train'], dic_y['train']

    #define the model
    model = keras.models.Sequential()

    model.add(keras.layers.Conv2D(32, (3, 3), activation='tanh', input_shape=X.shape[1:]))
    model.add(keras.layers.AveragePooling2D((3, 3)))

    model.add(keras.layers.Conv2D(16, (3, 3), activation='tanh'))
    model.add(keras.layers.AveragePooling2D((2, 2)))

    model.add(keras.layers.Conv2D(8, (3, 3), activation='tanh'))
    model.add(keras.layers.AveragePooling2D((2, 2)))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(1, activation='sigmoid', kernel_regularizer=keras.regularizers.l2(l=0.05)))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

    history = model.fit(X, y, epochs=15, batch_size=10, verbose=1)

    #Test model on different string tensions (higher and lower):
    tryout_x = []
    for key in dic_X.keys():
        if key=='train':
            continue
        scores = model.evaluate(dic_X[key], dic_y[key], return_dict=True, verbose=0)
        print('Model has accuracy of {acc} when evaluated on string tension of {key}.'.format(acc=scores['acc'], key=key))
        tryout_x.append(scores['acc'])

    tryout.append(tryout_x)
# Out:
# Epoch 1/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.7248 - acc: 0.5850
# Epoch 2/15
# 20/20 [==============================] - 8s 378ms/step - loss: 0.5082 - acc: 0.8450
# Epoch 3/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.1786 - acc: 0.9800
# Epoch 4/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.1265 - acc: 0.9850
# Epoch 5/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0574 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0383 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 7s 374ms/step - loss: 0.0327 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 8s 383ms/step - loss: 0.0295 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 7s 374ms/step - loss: 0.0195 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0168 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0155 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0152 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0133 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0133 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0107 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6200000047683716 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.7400000095367432 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.800000011920929 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 7s 375ms/step - loss: 0.7103 - acc: 0.5650
# Epoch 2/15
# 20/20 [==============================] - 8s 383ms/step - loss: 0.4272 - acc: 0.7850
# Epoch 3/15
# 20/20 [==============================] - 7s 374ms/step - loss: 0.2286 - acc: 0.9400
# Epoch 4/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0905 - acc: 0.9950
# Epoch 5/15
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0466 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 8s 385ms/step - loss: 0.0365 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0300 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0254 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0228 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0208 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0178 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 8s 384ms/step - loss: 0.0157 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0142 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0138 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0141 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.6800000071525574 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.699999988079071 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.8799999952316284 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.8399999737739563 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.8799999952316284 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8399999737739563 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 8s 378ms/step - loss: 0.7146 - acc: 0.6450
# Epoch 2/15
# 20/20 [==============================] - 8s 383ms/step - loss: 0.4071 - acc: 0.9200
# Epoch 3/15
# 20/20 [==============================] - 8s 386ms/step - loss: 0.1727 - acc: 0.9750
# Epoch 4/15
# 20/20 [==============================] - 7s 374ms/step - loss: 0.0797 - acc: 0.9950
# Epoch 5/15
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0538 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0390 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0317 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0295 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0234 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0208 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 7s 369ms/step - loss: 0.0191 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0166 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0159 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0159 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0174 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5199999809265137 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.6600000262260437 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.7599999904632568 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.6600000262260437 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.7599999904632568 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.7599999904632568 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 7s 358ms/step - loss: 0.7104 - acc: 0.5150
# Epoch 2/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.5636 - acc: 0.6450
# Epoch 3/15
# 20/20 [==============================] - 7s 360ms/step - loss: 0.3949 - acc: 0.8600
# Epoch 4/15
# 20/20 [==============================] - 7s 367ms/step - loss: 0.1209 - acc: 0.9950
# Epoch 5/15
# 20/20 [==============================] - 7s 361ms/step - loss: 0.0648 - acc: 0.9950
# Epoch 6/15
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0385 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 7s 358ms/step - loss: 0.0310 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 7s 364ms/step - loss: 0.0249 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 7s 362ms/step - loss: 0.0211 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 7s 361ms/step - loss: 0.0198 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 7s 360ms/step - loss: 0.0223 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 7s 360ms/step - loss: 0.0183 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 7s 359ms/step - loss: 0.0145 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 7s 356ms/step - loss: 0.0128 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 7s 365ms/step - loss: 0.0114 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6200000047683716 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.7400000095367432 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.800000011920929 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 8s 378ms/step - loss: 0.7132 - acc: 0.5450
# Epoch 2/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.4223 - acc: 0.9100
# Epoch 3/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.1518 - acc: 0.9650
# Epoch 4/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0734 - acc: 1.0000
# Epoch 5/15
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0493 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0381 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0317 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0287 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0243 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 7s 369ms/step - loss: 0.0225 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0199 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0178 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 8s 383ms/step - loss: 0.0151 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0138 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0131 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6200000047683716 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.7599999904632568 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.7799999713897705 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.9599999785423279 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.7065 - acc: 0.5650
# Epoch 2/15
# 20/20 [==============================] - 7s 371ms/step - loss: 0.5551 - acc: 0.6700
# Epoch 3/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.2632 - acc: 0.8900
# Epoch 4/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.1212 - acc: 0.9750
# Epoch 5/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0539 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0370 - acc: 0.9950
# Epoch 7/15
# 20/20 [==============================] - 8s 384ms/step - loss: 0.0261 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0207 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0175 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0166 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0152 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0128 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0123 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0116 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0106 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.6800000071525574 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.699999988079071 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.8600000143051147 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.8600000143051147 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.8799999952316284 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8799999952316284 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.7384 - acc: 0.5500
# Epoch 2/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.5887 - acc: 0.7800
# Epoch 3/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.2997 - acc: 0.8600
# Epoch 4/15
# 20/20 [==============================] - 7s 371ms/step - loss: 0.0980 - acc: 0.9900
# Epoch 5/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0627 - acc: 0.9950
# Epoch 6/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0397 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0325 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 7s 371ms/step - loss: 0.0266 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0259 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0263 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0195 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0153 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0136 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 7s 369ms/step - loss: 0.0139 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0123 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5199999809265137 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5799999833106995 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6200000047683716 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.7400000095367432 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.7799999713897705 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.9399999976158142 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.6978 - acc: 0.6900
# Epoch 2/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.3924 - acc: 0.8150
# Epoch 3/15
# 20/20 [==============================] - 8s 378ms/step - loss: 0.1198 - acc: 0.9900
# Epoch 4/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0644 - acc: 1.0000
# Epoch 5/15
# 20/20 [==============================] - 8s 385ms/step - loss: 0.0399 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0486 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0341 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0309 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0249 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0229 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0172 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0129 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0105 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0094 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0092 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5199999809265137 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6200000047683716 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.7200000286102295 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.7400000095367432 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8799999952316284 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 7s 363ms/step - loss: 0.7316 - acc: 0.5100
# Epoch 2/15
# 20/20 [==============================] - 7s 355ms/step - loss: 0.5798 - acc: 0.6700
# Epoch 3/15
# 20/20 [==============================] - 7s 364ms/step - loss: 0.1986 - acc: 0.9650
# Epoch 4/15
# 20/20 [==============================] - 7s 356ms/step - loss: 0.1107 - acc: 0.9850
# Epoch 5/15
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0565 - acc: 0.9950
# Epoch 6/15
# 20/20 [==============================] - 7s 354ms/step - loss: 0.0344 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 7s 363ms/step - loss: 0.0253 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 7s 356ms/step - loss: 0.0214 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 7s 360ms/step - loss: 0.0184 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 7s 359ms/step - loss: 0.0161 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 7s 358ms/step - loss: 0.0151 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 7s 357ms/step - loss: 0.0141 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 7s 356ms/step - loss: 0.0126 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 7s 363ms/step - loss: 0.0122 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 7s 353ms/step - loss: 0.0112 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5199999809265137 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.6000000238418579 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.6000000238418579 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6600000262260437 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.800000011920929 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.8600000143051147 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 1.0 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.9800000190734863 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.9800000190734863 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.9599999785423279 when evaluated on string tension of 2.5e-07.
# Epoch 1/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.7253 - acc: 0.5500
# Epoch 2/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.4353 - acc: 0.8350
# Epoch 3/15
# 20/20 [==============================] - 7s 367ms/step - loss: 0.1257 - acc: 0.9950
# Epoch 4/15
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0695 - acc: 1.0000
# Epoch 5/15
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0413 - acc: 1.0000
# Epoch 6/15
# 20/20 [==============================] - 8s 386ms/step - loss: 0.0350 - acc: 1.0000
# Epoch 7/15
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0256 - acc: 1.0000
# Epoch 8/15
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0224 - acc: 1.0000
# Epoch 9/15
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0208 - acc: 1.0000
# Epoch 10/15
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0170 - acc: 1.0000
# Epoch 11/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0145 - acc: 1.0000
# Epoch 12/15
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0152 - acc: 1.0000
# Epoch 13/15
# 20/20 [==============================] - 7s 371ms/step - loss: 0.0132 - acc: 1.0000
# Epoch 14/15
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0115 - acc: 1.0000
# Epoch 15/15
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0109 - acc: 1.0000
# Model has accuracy of 0.5 when evaluated on string tension of 1e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 3.1818181818181816e-08.
# Model has accuracy of 0.5400000214576721 when evaluated on string tension of 5.3636363636363635e-08.
# Model has accuracy of 0.5 when evaluated on string tension of 7.545454545454545e-08.
# Model has accuracy of 0.5600000023841858 when evaluated on string tension of 9.727272727272726e-08.
# Model has accuracy of 0.6200000047683716 when evaluated on string tension of 1.1909090909090907e-07.
# Model has accuracy of 0.699999988079071 when evaluated on string tension of 1.409090909090909e-07.
# Model has accuracy of 0.7599999904632568 when evaluated on string tension of 1.627272727272727e-07.
# Model has accuracy of 0.9200000166893005 when evaluated on string tension of 1.8454545454545454e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.0636363636363636e-07.
# Model has accuracy of 0.8999999761581421 when evaluated on string tension of 2.2818181818181816e-07.
# Model has accuracy of 0.8799999952316284 when evaluated on string tension of 2.5e-07.

# %%
(100*pd.DataFrame(tryout).std(axis=0)).to_list()
# Out:
# [0.0,
#  0.6324549288770788,
#  2.065590558813004,
#  2.2010105384210914,
#  2.1499358135572963,
#  2.86744271648833,
#  5.966574192751415,
#  5.921711431216838,
#  6.613118258447708,
#  8.66410199389412,
#  6.0516302922966645,
#  5.163977487146237]

# %%
(100*pd.DataFrame(tryout).mean(axis=0)).to_list()
# Out:
# [50.0,
#  50.19999980926514,
#  55.60000121593476,
#  52.2000002861023,
#  56.799999475479126,
#  61.000000238418586,
#  71.4000004529953,
#  75.799999833107,
#  91.20000004768372,
#  88.20000052452087,
#  90.799999833107,
#  87.99999833106995]

# %%
#data for training at 10^-7

#from smallest value in dic_X to biggest
try_1 = np.array([[54, 66, 74, 92, 92, 100, 98, 100, 100, 100, 100, 98], 
[54, 74, 94, 100, 100, 100, 100, 100, 100, 100, 100, 100],
[56, 78, 98, 100, 100, 100, 100, 100, 100, 100, 100, 100],
[54, 78, 98, 100, 100, 100, 100, 100, 100, 100, 100, 100],
[56, 76, 98, 100, 100, 100, 100, 100, 100, 100, 100, 100],
[51, 56, 66, 78, 81, 90, 92, 98, 100, 100, 100, 98],
[54, 74, 96, 100, 100, 100, 100, 100, 100, 100, 100, 100],
[57, 90, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]])
