# %%
from scaling_solution_signal import generate_signal
from gaussian_fluctuations import generate_gaussian

# %%
import matplotlib.pyplot as plt
import numpy as np
import copy
import matplotlib

# %% [markdown]
# We first generate the cosmic string signal using the "generate_signal()" function imported from scaling_solution_signal. The output is a 400x400 map.

# %%
m = generate_signal()
# Out:
# /home/william/Research/CosmicStrings/code/maps_generator/cosmic_string.py:114: RuntimeWarning: divide by zero encountered in double_scalars
#   signal = np.array([2*self.polarization_signal/depth]*depth)

# %% [markdown]
# We then generate a gaussian background.

# %%
m2 = generate_gaussian()
# Out:
# /home/william/Research/CosmicStrings/code/maps_generator/gaussian_fluctuations.py:54: RuntimeWarning: invalid value encountered in true_divide
#   return lmax2500CL[:len(ls), 2] *2*np.pi/(ls*(ls+1))

# %% [markdown]
# We then do stuff for the color scheme.

# %%
my_cmap = copy.copy(matplotlib.cm.get_cmap('inferno')) # copy the default cmap
my_cmap.set_bad((0,0,0))

# %% [markdown]
# ### Scaling solution polarization signal of cosmic strings

# %%
plt.imshow(m, cmap=my_cmap)
plt.colorbar()
plt.title(f"Polarization Signal for a \n Scaling Solution of Cosmic Strings \n with N = 3")
# Out:
# Text(0.5, 1.0, 'Polarization Signal for a \n Scaling Solution of Cosmic Strings \n with N = 3')

# %% [markdown]
# ### Gaussian fluctuations of the polarization signal

# %%
plt.imshow(m2, cmap=my_cmap)
plt.colorbar()

# %% [markdown]
# ### Cosmic String signal + Fluctuations signal combined

# %%
mult_factor = 10
plt.imshow(mult_factor*m+m2, cmap=my_cmap) #Note : Cosmic String signal rescaled
plt.colorbar()
