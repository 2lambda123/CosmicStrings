# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#string tensions

x = np.linspace(10**(-8), 2.5*10**(-7), 12)

y_1 = [50.0,50.19999980926514,55.60000121593476,52.2000002861023,56.799999475479126,61.000000238418586,
       71.4000004529953,75.799999833107,91.20000004768372,88.20000052452087,90.799999833107,
       87.99999833106995] #results when training at 5 x 10^-7
y_1err = [1.0,0.6324549288770788,2.065590558813004,2.2010105384210914,2.1499358135572963,2.86744271648833,
          5.966574192751415,5.921711431216838,6.613118258447708,8.66410199389412,6.0516302922966645,
          5.163977487146237]

y_2 = [ 54.5 , 74.0,90.5,96.25,96.625,98.75,98.75,99.75,100.0,100.0,100.0,99.5] #results when training at 10^-7
y_2err = [1.73205081,9.21954446,12.11404144,7.37817728,6.46021478,3.30718914,2.63391344,1,1,1,1,1]

y_3 = [60.600000619888306,80.00000059604645,89.19999957084656,94.79999959468842,95.40000021457672,
       97.19999969005585,96.19999885559082,98.00000011920929,98.79999995231628,97.7999997138977,
       98.40000033378601,97.40000009536743] #results when training at 5 x 10^-8
y_3err = [10.996969824839944,12.204849543204661,8.9542046334451,5.6725463040229585,5.581716294773017,
          4.23739964439179,4.565572744992174,4.000000158945769,3.1552432360881717,5.028806804264986,
          4.40201927146876,3.8930139876390815]

# %%
plt.rc('font', family='serif', size=16)
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

plt.figure(figsize = (14,8))
plt.errorbar(x, y_1, yerr=y_1err, marker='o', markersize=10, label=r'$G\mu = 5 \times 10^{-7}$')
plt.errorbar(x, y_2, yerr=y_2err, marker='s', markersize=10, label=r'$G\mu = 10^{-7}$')
plt.errorbar(x, y_3, yerr=y_3err, marker='*', markersize=18, label=r'$G\mu = 5 \times 10^{-8}$')
plt.xlabel('String Tension')
plt.ylabel('Accuracy')
xmin, xmax = plt.xlim()
plt.xlim(xmax, xmin)
plt.xticks(ticks=[10**(-8)] + list(10**(-7)*np.arange(0.5, 3, 0.5)), labels=[r'$1.0\times 10^{-8}$', r'$5.0\times 10^{-8}$',r'$1.0\times 10^{-7}$',r'$1.5\times 10^{-5}$',r'$2.0\times 10^{-7}$',r'$2.5\times 10^{-7}$'])
plt.hlines(50, xmin, xmax, color='black', label='Baseline', linestyle='dashed')
plt.legend(prop={'size': 14}, loc='center left', bbox_to_anchor=(0.05,0.3))
#plt.savefig('../figures/fixed_str_tension.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
